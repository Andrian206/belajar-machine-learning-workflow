# %% [markdown]
# Import Depedencies

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Loading Data

# %%
train = pd.read_csv('content/train.csv')
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# Loading Data (All Rows)

# %%
pd.set_option('display.max_rows',None)

train = pd.read_csv('content/train.csv')
# train

# %% [markdown]
# Loading Data (All Columns)

# %%
pd.set_option('display.max_columns', None)

train = pd.read_csv('content/train.csv')
# train

# %% [markdown]
# Displays summary of datasets

# %%
train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   str
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   str
#  6   Alley          91 non-null     str
#  7   LotShape       1460 non-null   str
#  8   LandContour    1460 non-null   str
#  9   Utilities      1460 non-null   str
#  10  LotConfig      1460 non-null   str
#  11  LandSlope      1460 non-null   str
#  12  Neighborhood   1460 non-null   str
#  13  Condition1     1460 non-null   str
#  14  Condition2     1460 non-null   str
#  15  BldgType       1460 non-null   str
#  16  HouseStyle     1460 non-null   str
#  17  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# Displays descriptive statistics

# %%
train.describe(include="all")
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %% [markdown]
# Checking of missing values

# %%
missing_values = train.isnull().sum()
missing_values[missing_values > 0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# Separated features by missing value (Numeric)

# %%
less = missing_values[missing_values < 1000].index
over = missing_values[missing_values >= 1000].index

# %% [markdown]
# Fill in the missing value (Numeric)

# %%
numeric_features = train[less].select_dtypes(include=['number']).columns
train[numeric_features] = train[numeric_features].fillna(train[numeric_features].median())

# %% [markdown]
# Fill in the missing value (Category)

# %%
categorical_feature = train[less].select_dtypes(include=['object', 'str']).columns

for column in categorical_feature:
    train[column] = train[column].fillna(train[column].mode()[0])

# %% [markdown]
# Deleting columns with too many missing values (over)

# %%
df = train.drop(columns=over)

# %% [markdown]
# Verify the datasets

# %%
missing_values = df.isnull().sum()
missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Checking of the outliers

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

selected_features = ['OverallQual', 'OverallCond']

for feature in selected_features:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df[feature])
    plt.title(f'Box Plot of {feature}')
    plt.show()

# %% [markdown]
# Identify outliers by IQR

# %%
Q1 = df[selected_features].quantile(0.25)
Q3 = df[selected_features].quantile(0.75)
IQR = Q3 - Q1

# %% [markdown]
# Delete outliers by IQR

# %%
condition = ~((df[selected_features] < (Q1 - 1.5 * IQR)) | (df[selected_features] > (Q3 + 1.5 * IQR))).any(axis=1)
df_filtered_selected = df.loc[condition, selected_features]

categorical_feature = train[less].select_dtypes(include=['object', 'str']).columns
df = pd.concat([df_filtered_selected, df.loc[condition, categorical_feature]], axis=1)

# %% [markdown]
# Verify the outliers

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

for feature in selected_features:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df[feature])
    plt.title(f'Box Plot of {feature} (After Cleaning)')
    plt.show()

# %% [markdown]
# Before standarization

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(train[selected_features[1]], kde=True)
plt.title("Histogram Sebelum Standardisasi")
# Out:
# Text(0.5, 1.0, 'Histogram Sebelum Standardisasi')

# %% [markdown]
# Standarization

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[selected_features]= scaler.fit_transform(df[selected_features])

# %% [markdown]
# After standarization

# %%
plt.subplot(1, 2, 2)
sns.histplot(df[selected_features[1]], kde=True)
plt.title("Histogram setelah Standardisasi")
# Out:
# Text(0.5, 1.0, 'Histogram setelah Standardisasi')

# %% [markdown]
# Duplicate data

# %%
duplicates = df.duplicated()

print(f"Jumlah duplikat: {duplicates.sum()}")
# Out:
# Jumlah duplikat: 21

# %% [markdown]
# Delete duplicate data

# %%
drop_duplicates = df.drop_duplicates()

print(f"Jumlah duplikat setelah dihapus: {drop_duplicates.duplicated().sum()}")
# Out:
# Jumlah duplikat setelah dihapus: 0
